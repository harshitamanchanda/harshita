# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitamanchanda/harshita/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# NAME- HARSHITA MANCHANDA
#
# ROLL NO - 20
#
# SEMESTER-3rd

# %% [markdown]
# # **New Section**

# %% [markdown]
# BANKING DATASET

# %%
df=pd.read_csv("banking_datasets.csv")
df
# Out:
#       Customer ID First Name Last Name  Age  Gender       Address  \
# 0               1     Joshua      Hall   45    Male     Address_1
# 1               2       Mark    Taylor   47  Female     Address_2
# 2               3     Joseph    Flores   25  Female     Address_3
# 3               4      Kevin       Lee   52   Other     Address_4
# 4               5      Linda   Johnson   68   Other     Address_5
# ...           ...        ...       ...  ...     ...           ...
# 4995         4996      Emily   Sanchez   21   Other  Address_4996
# 4996         4997    Melissa     Perez   27  Female  Address_4997
# 4997         4998    Timothy    Walker   45  Female  Address_4998
# 4998         4999    Deborah    Nelson   58  Female  Address_4999
# 4999         5000     Daniel  Martinez   35    Male  Address_5000
#
#                City  Contact Number                    Email Account Type  \
# 0        Fort Worth     19458794854      joshua.hall@kag.com      Current
# ...

# %%
#1. what is the shape of data set?

# %%
df.shape
# Out:
# (5000, 40)

# %%
#2.Displays the first 10 rows of the dataset

# %%
df.head(10)
# Out:
#    Customer ID   First Name Last Name  Age  Gender     Address           City  \
# 0            1       Joshua      Hall   45    Male   Address_1     Fort Worth
# 1            2         Mark    Taylor   47  Female   Address_2     Louisville
# 2            3       Joseph    Flores   25  Female   Address_3   Philadelphia
# 3            4        Kevin       Lee   52   Other   Address_4  Oklahoma City
# 4            5        Linda   Johnson   68   Other   Address_5        Phoenix
# 5            6      Charles    Torres   52    Male   Address_6        El Paso
# 6            7       Joshua    Garcia   43    Male   Address_7         Dallas
# 7            8  Christopher     Baker   47    Male   Address_8        Memphis
# 8            9       Daniel     Moore   52    Male   Address_9   Indianapolis
# 9           10      William  Robinson   55   Other  Address_10     Washington
#
#    Contact Number                      Email Account Type  ...  \
# ...

# %%
#3.What are the columns name?

# %%
df.columns
# Out:
# Index(['Customer ID', 'First Name', 'Last Name', 'Age', 'Gender', 'Address',
#        'City', 'Contact Number', 'Email', 'Account Type', 'Account Balance',
#        'Date Of Account Opening', 'Last Transaction Date', 'TransactionID',
#        'Transaction Date', 'Transaction Type', 'Transaction Amount',
#        'Account Balance After Transaction', 'Branch ID', 'Loan ID',
#        'Loan Amount', 'Loan Type', 'Interest Rate', 'Loan Term',
#        'Approval/Rejection Date', 'Loan Status', 'CardID', 'Card Type',
#        'Credit Limit', 'Credit Card Balance', 'Minimum Payment Due',
#        'Payment Due Date', 'Last Credit Card Payment Date', 'Rewards Points',
#        'Feedback ID', 'Feedback Date', 'Feedback Type', 'Resolution Status',
#        'Resolution Date', 'Anomaly'],
#       dtype='object')

# %%
#4. What are the datatypes of each column?

# %%
df.dtypes
# Out:
# Customer ID                            int64
# First Name                            object
# Last Name                             object
# Age                                    int64
# Gender                                object
# Address                               object
# City                                  object
# Contact Number                         int64
# Email                                 object
# Account Type                          object
# Account Balance                      float64
# Date Of Account Opening               object
# Last Transaction Date                 object
# TransactionID                          int64
# Transaction Date                      object
# Transaction Type                      object
# Transaction Amount                   float64
# Account Balance After Transaction    float64
# Branch ID                              int64
# Loan ID                                int64
# Loan Amount                          float64
# ...

# %%
#5.How many missing values are  there in each column?

# %%
df.isnull().sum()
# Out:
# Customer ID                          0
# First Name                           0
# Last Name                            0
# Age                                  0
# Gender                               0
# Address                              0
# City                                 0
# Contact Number                       0
# Email                                0
# Account Type                         0
# Account Balance                      0
# Date Of Account Opening              0
# Last Transaction Date                0
# TransactionID                        0
# Transaction Date                     0
# Transaction Type                     0
# Transaction Amount                   0
# Account Balance After Transaction    0
# Branch ID                            0
# Loan ID                              0
# Loan Amount                          0
# Loan Type                            0
# Interest Rate                        0
# Loan Term                            0
# ...

# %%
#6.what are the unique account types?

# %%
df["Account Type"].unique()
# Out:
# array(['Current', 'Savings'], dtype=object)

# %%
#7. How many male,female and other coustomers are there ?

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Female    1727
# Other     1639
# Male      1634
# Name: count, dtype: int64

# %%
#8.what is the average age of the customer?

# %%
df["Age"].mean()
# Out:
# np.float64(43.4698)

# %%
#9.Select all rows where Gender is 'Female'.

# %%
df[df['Gender'] == 'Female']
# Out:
#       Customer ID First Name Last Name  Age  Gender       Address  \
# 1               2       Mark    Taylor   47  Female     Address_2
# 2               3     Joseph    Flores   25  Female     Address_3
# 11             12      Nancy     Allen   37  Female    Address_12
# 12             13   Margaret  Robinson   63  Female    Address_13
# 13             14   Michelle    Taylor   48  Female    Address_14
# ...           ...        ...       ...  ...     ...           ...
# 4982         4983     Thomas     Young   66  Female  Address_4983
# 4992         4993       Paul     Davis   56  Female  Address_4993
# 4996         4997    Melissa     Perez   27  Female  Address_4997
# 4997         4998    Timothy    Walker   45  Female  Address_4998
# 4998         4999    Deborah    Nelson   58  Female  Address_4999
#
#                   City  Contact Number                      Email  \
# 1           Louisville     19458794855        mark.taylor@kag.com
# ...

# %%
#10.Customers with Reward Points greater than 5000.

# %%
df[df['Rewards Points'] > 5000]
# Out:
#       Customer ID   First Name Last Name  Age  Gender       Address  \
# 0               1       Joshua      Hall   45    Male     Address_1
# 3               4        Kevin       Lee   52   Other     Address_4
# 6               7       Joshua    Garcia   43    Male     Address_7
# 7               8  Christopher     Baker   47    Male     Address_8
# 9              10      William  Robinson   55   Other    Address_10
# ...           ...          ...       ...  ...     ...           ...
# 4990         4991         Mark     Moore   51    Male  Address_4991
# 4994         4995      Richard     Young   62   Other  Address_4995
# 4995         4996        Emily   Sanchez   21   Other  Address_4996
# 4996         4997      Melissa     Perez   27  Female  Address_4997
# 4997         4998      Timothy    Walker   45  Female  Address_4998
#
#                City  Contact Number                      Email Account Type  \
# ...

# %%
#11.Customers whose Resolution Status is 'Pending'.

# %%
df[df['Resolution Status'] == 'Pending']
# Out:
#       Customer ID   First Name Last Name  Age  Gender       Address  \
# 2               3       Joseph    Flores   25  Female     Address_3
# 6               7       Joshua    Garcia   43    Male     Address_7
# 7               8  Christopher     Baker   47    Male     Address_8
# 8               9       Daniel     Moore   52    Male     Address_9
# 10             11      William     Perez   28    Male    Address_11
# ...           ...          ...       ...  ...     ...           ...
# 4984         4985       Daniel     Baker   43    Male  Address_4985
# 4991         4992      Timothy    Thomas   35   Other  Address_4992
# 4995         4996        Emily   Sanchez   21   Other  Address_4996
# 4996         4997      Melissa     Perez   27  Female  Address_4997
# 4998         4999      Deborah    Nelson   58  Female  Address_4999
#
#               City  Contact Number                      Email Account Type  \
# ...

# %%
#12. Customers who gave ‘Praise’ feedback.

# %%
df[df['Feedback Type'] == 'Praise']
# Out:
#       Customer ID First Name Last Name  Age  Gender       Address  \
# 2               3     Joseph    Flores   25  Female     Address_3
# 5               6    Charles    Torres   52    Male     Address_6
# 12             13   Margaret  Robinson   63  Female    Address_13
# 13             14   Michelle    Taylor   48  Female    Address_14
# 17             18       Mary    Wilson   45  Female    Address_18
# ...           ...        ...       ...  ...     ...           ...
# 4976         4977     Joshua     Lopez   57    Male  Address_4977
# 4979         4980     Robert      Hill   46   Other  Address_4980
# 4992         4993       Paul     Davis   56  Female  Address_4993
# 4993         4994     Daniel    Harris   33   Other  Address_4994
# 4994         4995    Richard     Young   62   Other  Address_4995
#
#                   City  Contact Number                      Email  \
# 2         Philadelphia     19458794856      joseph.flores@kag.com
# ...

# %%
#13.Sort by Payment Due Date (oldest to newest).

# %%
df.sort_values(by='Payment Due Date')
# Out:
#       Customer ID   First Name  Last Name  Age  Gender       Address  \
# 2067         2068        Sarah   Campbell   32  Female  Address_2068
# 1668         1669      Melissa       Hill   30    Male  Address_1669
# 3891         3892        Linda       Hill   55  Female  Address_3892
# 4527         4528         John      Perez   24  Female  Address_4528
# 224           225  Christopher    Ramirez   46  Female   Address_225
# ...           ...          ...        ...  ...     ...           ...
# 4546         4547       Ashley  Hernandez   60  Female  Address_4547
# 1654         1655     Jennifer    Ramirez   29    Male  Address_1655
# 2567         2568        Susan      Perez   47   Other  Address_2568
# 2970         2971        Susan   Gonzalez   19    Male  Address_2971
# 2356         2357      Richard      Moore   33    Male  Address_2357
#
#              City  Contact Number                        Email Account Type  \
# ...

# %%
#14. Total reward points by Resolution Status.

# %%
df.groupby('Resolution Status')['Rewards Points'].sum()
# Out:
# Resolution Status
# Pending     12340634
# Resolved    12490175
# Name: Rewards Points, dtype: int64

# %%
#15.Number of complaints by Feedback Type.

# %%
df['Feedback Type'].value_counts()
# Out:
# Feedback Type
# Suggestion    1689
# Complaint     1681
# Praise        1630
# Name: count, dtype: int64

# %%
#16. Male customers with more than 8000 rewards.

# %%
df[(df['Gender'] == 'Male') & (df['Rewards Points'] > 8000)]
# Out:
#       Customer ID First Name Last Name  Age Gender       Address         City  \
# 0               1     Joshua      Hall   45   Male     Address_1   Fort Worth
# 54             55       John  Campbell   41   Male    Address_55      Seattle
# 59             60      Susan      Hill   28   Male    Address_60      Seattle
# 82             83     Daniel   Sanchez   18   Male    Address_83      Houston
# 121           122   Kimberly    Carter   58   Male   Address_122     San Jose
# ...           ...        ...       ...  ...    ...           ...          ...
# 4934         4935  Elizabeth    Torres   26   Male  Address_4935  Kansas City
# 4959         4960      Emily   Jackson   34   Male  Address_4960    Nashville
# 4961         4962     Robert    Nguyen   24   Male  Address_4962   Sacramento
# 4986         4987    Michael    Wright   68   Male  Address_4987      Seattle
# 4990         4991       Mark     Moore   51   Male  Address_4991     San Jose
#
# ...

# %%
#17.Female customers with 'Savings' account and resolved complaints.

# %%
df[(df['Gender'] == 'Female') &
   (df['Account Type'] == 'Savings') &
   (df['Resolution Status'] == 'Resolved')]
# Out:
#       Customer ID First Name Last Name  Age  Gender       Address  \
# 12             13   Margaret  Robinson   63  Female    Address_13
# 13             14   Michelle    Taylor   48  Female    Address_14
# 17             18       Mary    Wilson   45  Female    Address_18
# 23             24    Charles     Adams   30  Female    Address_24
# 55             56     Amanda  Gonzalez   69  Female    Address_56
# ...           ...        ...       ...  ...     ...           ...
# 4967         4968     Joshua    Walker   65  Female  Address_4968
# 4968         4969    Jessica     Baker   60  Female  Address_4969
# 4980         4981      Carol     Moore   69  Female  Address_4981
# 4982         4983     Thomas     Young   66  Female  Address_4983
# 4992         4993       Paul     Davis   56  Female  Address_4993
#
#                   City  Contact Number                      Email  \
# 12            Columbus     19458794866  margaret.robinson@kag.com
# ...

# %%
#18.Show a pie chart of Account Type distribution.

# %%
df['Account Type'].value_counts().plot(kind='pie', autopct='%1.1f%%', title='Account Type Distribution')
# Out:
# <Axes: title={'center': 'Account Type Distribution'}, ylabel='count'>

# %%
#19.  Plot the number of customers by Gender using a bar chart.

#Question: How many male and female customers are there?

# %%
df['Gender'].value_counts().plot(kind='bar', title='Customer Count by Gender')
# Out:
# <Axes: title={'center': 'Customer Count by Gender'}, xlabel='Gender'>

# %%
#20.Create a line plot of total rewards by Payment Due Date.

#Question: How do rewards points change over the due date timeline?

# %%
df_sorted = df.sort_values('Payment Due Date')
df_sorted.groupby('Payment Due Date')['Rewards Points'].sum().plot(kind='line', title='Rewards Over Time')
# Out:
# <Axes: title={'center': 'Rewards Over Time'}, xlabel='Payment Due Date'>

# %%
#21.Select only 'First Name', 'City', 'Rewards Points' columns.

# %%
df[['First Name', 'City', 'Rewards Points']]
# Out:
#      First Name           City  Rewards Points
# 0        Joshua     Fort Worth            8142
# 1          Mark     Louisville            4306
# 2        Joseph   Philadelphia            4842
# 3         Kevin  Oklahoma City            9463
# 4         Linda        Phoenix            2209
# ...         ...            ...             ...
# 4995      Emily           Mesa            7530
# 4996    Melissa    Los Angeles            8796
# 4997    Timothy     Louisville            9966
# 4998    Deborah        Detroit             538
# 4999     Daniel        El Paso            1816
#
# [5000 rows x 3 columns]

# %%
#22. Access row where Customer ID is 5.

# %%
df[df['Customer ID'] == 5]
# Out:
#    Customer ID First Name Last Name  Age Gender    Address     City  \
# 4            5      Linda   Johnson   68  Other  Address_5  Phoenix
#
#    Contact Number                  Email Account Type  ...  \
# 4     19458794858  linda.johnson@kag.com      Savings  ...
#
#    Minimum Payment Due Payment Due Date Last Credit Card Payment Date  \
# 4                 1.29         3/4/2023                     7/27/2023
#
#    Rewards Points Feedback ID Feedback Date  Feedback Type  Resolution Status  \
# 4            2209           5     2/12/2023      Complaint           Resolved
#
#    Resolution Date  Anomaly
# 4       11/21/2023        1
#
# [1 rows x 40 columns]

# %%
#23.Feedbacks with type 'Complaint' and status 'Pending'.

# %%
df[(df['Feedback Type'] == 'Complaint') & (df['Resolution Status'] == 'Pending')]
# Out:
#       Customer ID   First Name Last Name  Age  Gender       Address  \
# 6               7       Joshua    Garcia   43    Male     Address_7
# 7               8  Christopher     Baker   47    Male     Address_8
# 10             11      William     Perez   28    Male    Address_11
# 11             12        Nancy     Allen   37  Female    Address_12
# 15             16      Michael     Young   29    Male    Address_16
# ...           ...          ...       ...  ...     ...           ...
# 4978         4979      Kenneth    Harris   44  Female  Address_4979
# 4991         4992      Timothy    Thomas   35   Other  Address_4992
# 4995         4996        Emily   Sanchez   21   Other  Address_4996
# 4996         4997      Melissa     Perez   27  Female  Address_4997
# 4998         4999      Deborah    Nelson   58  Female  Address_4999
#
#                City  Contact Number                      Email Account Type  \
# ...

# %%
#24. Male customers with 'Savings' account and resolved complaints.

# %%
df[(df['Gender'] == 'Male') &
   (df['Account Type'] == 'Savings') &
   (df['Resolution Status'] == 'Resolved')]
# Out:
#       Customer ID   First Name Last Name  Age Gender       Address  \
# 5               6      Charles    Torres   52   Male     Address_6
# 24             25       Steven   Ramirez   29   Male    Address_25
# 65             66         Mary     Jones   41   Male    Address_66
# 67             68        Carol    Carter   68   Male    Address_68
# 70             71        Karen    Carter   59   Male    Address_71
# ...           ...          ...       ...  ...    ...           ...
# 4943         4944  Christopher     Adams   48   Male  Address_4944
# 4952         4953       Daniel    Carter   36   Male  Address_4953
# 4974         4975        Brian     Adams   28   Male  Address_4975
# 4986         4987      Michael    Wright   68   Male  Address_4987
# 4987         4988       Ashley      King   27   Male  Address_4988
#
#              City  Contact Number                      Email Account Type  \
# 5         El Paso     19458794859     charles.torres@kag.com      Savings
# ...

# %%
#25.Compare average Minimum Payment Due by Account Type and plot it.

# %%
df.groupby('Account Type')['Minimum Payment Due'].mean().plot(kind='bar', title='Avg Minimum Payment by Account Type')
# Out:
# <Axes: title={'center': 'Avg Minimum Payment by Account Type'}, xlabel='Account Type'>

# %%
#26.Create a correlation matrix for all numeric columns.

# %%
df.corr(numeric_only=True)
# Out:
#                                    Customer ID       Age  Contact Number  \
# Customer ID                           1.000000  0.000777        1.000000
# Age                                   0.000777  1.000000        0.000777
# Contact Number                        1.000000  0.000777        1.000000
# Account Balance                      -0.002638  0.017297       -0.002638
# TransactionID                         1.000000  0.000777        1.000000
# Transaction Amount                   -0.020744  0.024801       -0.020744
# Account Balance After Transaction    -0.006431  0.015723       -0.006431
# Branch ID                             0.004664  0.023981        0.004664
# Loan ID                               1.000000  0.000777        1.000000
# Loan Amount                          -0.005764 -0.035130       -0.005764
# Interest Rate                        -0.019405  0.007355       -0.019405
# Loan Term                            -0.009246 -0.017062       -0.009246
# ...

# %%
#26.  What is the most common Feedback ID?

# %%
df['Feedback ID'].value_counts().idxmax()
# Out:
# np.int64(5000)

# %%
#27. Show the number of customers in each city using a stats(line, bar,pie,histogram)

# %%
df['City'].value_counts().plot(kind='hist', title='Customer Count by City')
# Out:
# <Axes: title={'center': 'Customer Count by City'}, ylabel='Frequency'>

# %%
df['City'].value_counts().plot(kind='bar', title='Customer Count by City')
# Out:
# <Axes: title={'center': 'Customer Count by City'}, xlabel='City'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))  # Adjust the width and height here
df['City'].value_counts().plot(kind='line', title='Customer Count by City')
plt.show()

# %%
#28. How many customers have zero rewards points?

# %%
df[df['Rewards Points'] == 0].shape[0]
# Out:
# 0

# %%
#29. How many customers have the same email address more than once?

# %%
df['Email'].duplicated().sum()
# Out:
# np.int64(2861)

# %%
#30.  Find top 5 customers with highest Minimum Payment Due.

# %%
df.sort_values(by='Minimum Payment Due', ascending=False).head(5)
# Out:
#       Customer ID First Name  Last Name  Age Gender       Address  \
# 104           105      Linda  Hernandez   27   Male   Address_105
# 3160         3161     Ronald   Anderson   38  Other  Address_3161
# 2284         2285      James     Harris   18  Other  Address_2285
# 704           705      Emily     Taylor   43   Male   Address_705
# 4509         4510       Mark   Thompson   35  Other  Address_4510
#
#              City  Contact Number                    Email Account Type  ...  \
# 104        Austin     19458794958  linda.hernandez@kag.com      Savings  ...
# 3160  Kansas City     19458798014  ronald.anderson@kag.com      Savings  ...
# 2284      Atlanta     19458797138     james.harris@kag.com      Savings  ...
# 704     Milwaukee     19458795558     emily.taylor@kag.com      Current  ...
# 4509  Los Angeles     19458799363    mark.thompson@kag.com      Savings  ...
#
#       Minimum Payment Due Payment Due Date Last Credit Card Payment Date  \
# ...

# %%
#31. Which Feedback ID is most common among customers over age 50?

# %%
df[df['Age'] > 50]['Feedback ID'].value_counts().idxmax()
# Out:
# np.int64(4999)

# %%
#32. Compare Account Type vs Rewards Points

# %%
df.groupby('Account Type')['Rewards Points'].mean().plot(kind="bar",title="account type vs record type ")
# Out:
# <Axes: title={'center': 'account type vs record type '}, xlabel='Account Type'>

# %%
#33. City vs Customer Count

# %%
df['City'].value_counts().head(5).plot(kind="bar",title="city vs customer count")
# Out:
# <Axes: title={'center': 'city vs customer count'}, xlabel='City'>

# %%
import numpy as np

# %%
#34.Plot a bar chart of customers by Account Type.

# %%
import matplotlib.pyplot as plt

df['Account Type'].value_counts().plot(kind='bar')
plt.title('Customers by Account Type')
plt.xlabel('Account Type')
plt.ylabel('Count')
plt.show()

# %%
#35. Plot a histogram of customer ages.

# %%
plt.hist(df['Age'].values, bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Customer Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#36.plt.hist(df['Age'].values, bins=10, color='skyblue', edgecolor='black')

# %%
plt.title('Distribution of Customer Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
#37.Count of Feedback Types

# %%
sns.countplot(data=df, x='Feedback Type')
plt.title('Count of Feedback Types')
plt.show()

# %%
#  --------- ---------  KEY FINDINGS FROM THE BANKING DATASET    ---------------  -----------    #

# %%
#1.DATA OVERVIEW
  #.Data size is 5000customers*40columns
#1.2.ACCOUNT TYPES
  #.Mostly current and saving
#1.3. GENDER AND AGE
  # Mix of Male, Female, and Other. Ages range from under 25 to over 50.
#1.4. CITIES
  #High customer count in cities like Fort Worth, Phoenix, Philadelphia.
#1.5. PAYMENT ISSUES
  # Some customers have very low Payment Due (₹1–₹2), others very high (₹200+).
#1.6. FEEDBACK
  # Feedback types include Complaints, Suggestions, and Praise. Some are still Pending resolution.
#1.7. REWARD POINTS
  # Some customers have very high points (9000+), indicating loyal or high-spending users.
#1.8. DATE COLUMNS
  # Can be used to find overdue payments and resolution delays.


#2.FINDINGS FROM COMPARISON BASED ANALYSIS

#2.1 GENDER VS PAYMENT DUE
  #You’ll see if Male, Female, or Other customers have higher average dues — helpful for targeted financial planning.
#2.2 ACCOUNT TYPE VS RECORD POINTS
  #You’ll know which account holders (Current/Savings) earn more rewards, possibly indicating more usage or loyalty.
#2.2 CITY VS CUSTOMER COUNT
  #Shows the top-performing branches/regions in terms of customer base — useful for marketing or expansion.
#2.3 FEEDBACK TYPE VS RESOLUTION STATUS
  #Helps find whether complaints are being resolved efficiently or still pending — useful for improving service.
#2.4 AGE GROUP VS PAYMENT DUE
  # Tells which age groups owe more on average — useful for risk analysis or customer support.
